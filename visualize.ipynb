# %% [markdown]
# # Load DataFrame

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data setup
data = pd.read_csv('employee_data.csv')

df = pd.DataFrame(data)
df
# Out:
#     EmployeeID             Name   Department     Salary  Age DateOfJoining  \
# 0        61069    Daniel Fisher        Sales  108538.56   58    2024-08-20
# 1        76556   Alicia Gilmore           HR   63889.01   46    2022-12-13
# 2        62518       Guy Molina      Finance   99801.25   56    2024-05-16
# 3        54921     Morgan Marsh  Engineering   57553.73   49    2024-08-07
# 4        63993  Jeffrey Johnson           HR   93509.89   47    2021-09-21
# ..         ...              ...          ...        ...  ...           ...
# 95       88835  Patricia Becker    Marketing   70509.14   44    2020-09-13
# 96       12735     Maria Parker        Sales  118235.56   47    2022-04-05
# 97       75965  Carlos Browning      Finance   99613.77   40    2021-09-03
# 98       54460      Carlos Ryan      Finance  104154.56   36    2024-12-23
# 99       69579    Denise Martin   Operations  100446.19   30    2024-09-07
#
#     PerformanceScore
# 0                2.4
# 1                4.4
# ...

# %% [markdown]
# # Get DataFrame Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        100 non-null    int64
#  1   Name              100 non-null    object
#  2   Department        100 non-null    object
#  3   Salary            100 non-null    float64
#  4   Age               100 non-null    int64
#  5   DateOfJoining     100 non-null    object
#  6   PerformanceScore  100 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# # Calculate average performance score by department

# %%
# Calculate average performance score by department

def avg_performance():
    avg_performance = df.groupby('Department')['PerformanceScore'].mean()

# Plotting
    plt.figure(figsize=(10, 6))
    avg_performance.plot(kind='bar', color='skyblue')
    plt.title('Average Performance Score by Department')
    plt.xlabel('Department')
    plt.ylabel('Average Performance Score')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

avg_performance()

# %% [markdown]
# # Scatter Plot of Age vs. Salary with Performance Color Coding

# %%
def age_vs_salary():
    plt.figure(figsize=(10, 6))
    scatter = plt.scatter(df['Age'], df['Salary'], c=df['PerformanceScore'], cmap='viridis', s=100)
    plt.title('Age vs Salary with Performance Score Color-Coding')
    plt.xlabel('Age')
    plt.ylabel('Salary')
    plt.colorbar(scatter, label='Performance Score')
    plt.tight_layout()
    plt.show()
    
age_vs_salary()

# %% [markdown]
# # Line Plot of Salary Over Time (Joining Date)

# %%
# Convert the DateOfJoining to datetime
def SalaryOverTime():
    df['DateOfJoining'] = pd.to_datetime(df['DateOfJoining'])

    # Sort by Date of Joining
    df_sorted = df.sort_values(by='DateOfJoining')

    plt.figure(figsize=(10, 6))
    plt.plot(df_sorted['DateOfJoining'], df_sorted['Salary'], marker='o', color='green', linestyle='-', markersize=6)
    plt.title('Salary Trend Over Time by Date of Joining')
    plt.xlabel('Date of Joining')
    plt.ylabel('Salary')
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.show()
SalaryOverTime()

# %%
x = np.linspace(1, 10, 100)
y = np.exp(x)

plt.plot(x, y)
plt.xscale('log')
plt.yscale('log')
plt.title('Logarithmic Plot')
plt.show()
