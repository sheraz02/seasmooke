# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dry_Eye_Dataset.csv")
# male = []
# female = []
# for i in range(len(df['Gender'])):
#     if df['Gender'][i] == 'M':
#         male.append(df['Gender'][i])
#     else:
#         female.append(df['Gender'][i])
# # len(male)
# len(female)

# df.info()
# df.shape
# df.describe().T
# df.head()
# df.tail()
# df.isnull().sum()
df.head()
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level  Heart rate  \
# 0      F   24             9.5              2             1          67
# 1      M   39             9.6              2             3          60
# 2      F   45             5.4              1             5          95
# 3      F   45             5.4              4             5          78
# 4      F   42             5.7              3             2          72
#
#    Daily steps  Physical activity  Height  Weight  ... Ongoing medication  \
# 0         3000                 31     161      69  ...                  Y
# 1        12000                 74     164      87  ...                  Y
# 2        12000                 93     179      94  ...                  N
# 3        19000                 32     160      77  ...                  N
# 4         4000                173     179      99  ...                  N
#
#   Smart device before bed Average screen time Blue-light filter  \
# ...

# %% [markdown]
# # Gender Distriubution (Male vs Female)

# %%
# Count the occurrences of each gender
gender_counts = df['Gender'].value_counts()

# Function to format the labels with both count and percentage
def func(pct, allvals):
    absolute = int(pct / 100.*sum(allvals))  # Calculate the absolute count
    return f"{absolute} ({pct:.1f}%)"  # Format: count (percentage)

# Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct=lambda pct: func(pct, gender_counts), startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.show()

# Print the count of males and females
print(f"Count of Males: {gender_counts['M']}")
print(f"Count of Females: {gender_counts['F']}")
# Out:
# Count of Males: 10028
# Count of Females: 9972

# %% [markdown]
# # Age Distribution Graph

# %%
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# # Sleep Duration Distribution

# %%
sns.histplot(df['Sleep duration'], kde=True, color='teal')
plt.title('Sleep Duration Distribution')
plt.show()

# %%
sns.boxplot(x="Sleep quality", y="Stress level", data=df)
plt.title("Sleep Quality vs Stress Level")
plt.show()

# %% [markdown]
# # Physical Activity vs Heart Rate

# %%
# Physical Activity vs Heart Rate
sns.scatterplot(x="Physical activity", y="Heart rate", data=df.head(1000))
plt.title('Physical Activity vs Heart Rate')
plt.show()

# %% [markdown]
# # Stress Level vs Sleep Duration

# %%
# Stress Level vs Sleep Duration
sns.scatterplot(x="Stress level", y="Sleep duration", data=df)
plt.title('Stress Level vs Sleep Duration')
plt.show()

# %% [markdown]
# # Calculate BMI

# %%
# Calculate BMI
df['Height (m)'] = df['Height'] / 100  # Convert height to meters
df['BMI'] = df['Weight'] / df['Height (m)']**2

# Plot BMI distribution
sns.histplot(df['BMI'], kde=True, color='purple', bins=10)
plt.title('BMI Distribution')
plt.show()

# %% [markdown]
# # Combined histograms for Age and Sleep Duration

# %%
# Combined histograms for Age and Sleep Duration
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Age Histogram
sns.histplot(df['Age'], kde=True, color='teal', bins=10, ax=axes[0])
axes[0].set_title('Age Distribution', fontsize=16)
axes[0].set_xlabel('Age', fontsize=14)
axes[0].set_ylabel('Frequency', fontsize=14)

# Sleep Duration Histogram
sns.histplot(df['Sleep duration'], kde=True, color='orange', bins=10, ax=axes[1])
axes[1].set_title('Sleep Duration Distribution', fontsize=16)
axes[1].set_xlabel('Sleep Duration (hours)', fontsize=14)
axes[1].set_ylabel('Frequency', fontsize=14)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplot for Age vs Dry Eye Disease

# %%
# Boxplot for Age vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.boxplot(x='Dry Eye Disease', y='Age', data=df, palette='Set2')
plt.title('Age vs Dry Eye Disease', fontsize=16)
plt.xlabel('Dry Eye Disease (Y/N)', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_58843/368252489.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dry Eye Disease', y='Age', data=df, palette='Set2')

# %% [markdown]
# # Boxplot for Sleep Duration vs Dry Eye Disease

# %%
# Boxplot for Sleep Duration vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.boxplot(x='Dry Eye Disease', y='Sleep duration', data=df, palette='Set2')
plt.title('Sleep Duration vs Dry Eye Disease', fontsize=16)
plt.xlabel('Dry Eye Disease (Y/N)', fontsize=14)
plt.ylabel('Sleep Duration (hours)', fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_58843/1430416559.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dry Eye Disease', y='Sleep duration', data=df, palette='Set2')

# %% [markdown]
# # Countplot for Caffeine Consumption vs Dry Eye Disease

# %%
# Countplot for Caffeine Consumption vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Caffeine consumption', hue='Dry Eye Disease', data=df, palette='Set1')
plt.title('Caffeine Consumption vs Dry Eye Disease', fontsize=16)
plt.xlabel('Caffeine Consumption (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %% [markdown]
# # Countplot for Smoking vs Dry Eye Disease

# %%
# Countplot for Smoking vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Smoking', hue='Dry Eye Disease', data=df, palette='Set1')
plt.title('Smoking vs Dry Eye Disease', fontsize=16)
plt.xlabel('Smoking (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %% [markdown]
# # Violin plot for Heart Rate vs Dry Eye Disease

# %%
# Violin plot for Heart Rate vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.violinplot(x='Dry Eye Disease', y='Heart rate', data=df, palette='Set2')
plt.title('Heart Rate vs Dry Eye Disease', fontsize=16)
plt.xlabel('Dry Eye Disease (Y/N)', fontsize=14)
plt.ylabel('Heart Rate (bpm)', fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_58843/1419212091.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Dry Eye Disease', y='Heart rate', data=df, palette='Set2')

# %% [markdown]
# # Scatter plot for Stress Level vs Sleep Duration with Dry Eye Disease as hue

# %%
# Scatter plot for Stress Level vs Sleep Duration with Dry Eye Disease as hue
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Stress level', y='Sleep duration', hue='Dry Eye Disease', data=df, palette='Set1', s=100)
plt.title('Stress Level vs Sleep Duration by Dry Eye Disease', fontsize=16)
plt.xlabel('Stress Level', fontsize=14)
plt.ylabel('Sleep Duration (hours)', fontsize=14)
plt.show()

# %% [markdown]
# # Countplot for Redness in Eye vs Dry Eye Disease

# %%
# Countplot for Redness in Eye vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Redness in eye', hue='Dry Eye Disease', data=df, palette='Set1')

# Titles and labels
plt.title('Redness in Eye vs Dry Eye Disease', fontsize=16)
plt.xlabel('Redness in Eye (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

#

# %% [markdown]
# # Countplot for Itchiness/Irritation in Eye vs Dry Eye Disease

# %%
# Countplot for Itchiness/Irritation in Eye vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Itchiness/Irritation in eye', hue='Dry Eye Disease', data=df, palette='Set1')

# Titles and labels
plt.title('Itchiness/Irritation in Eye vs Dry Eye Disease', fontsize=16)
plt.xlabel('Itchiness/Irritation in Eye (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %% [markdown]
# # Countplot for Discomfort Eye Strain vs Redness in Eye vs Dry Eye Disease

# %%
# Countplot for Discomfort Eye Strain vs Redness in Eye vs Dry Eye Disease
plt.figure(figsize=(12, 6))
sns.countplot(x='Discomfort Eye-strain', hue='Redness in eye', data=df, palette='Set2', hue_order=['Y', 'N'])

# Titles and labels
plt.title('Discomfort Eye Strain and Redness in Eye vs Dry Eye Disease', fontsize=16)
plt.xlabel('Discomfort Eye Strain (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Redness in Eye', loc='upper right', labels=['Yes', 'No'])
plt.show()

# %% [markdown]
# # Countplot for Blue Light Filter vs Dry Eye Disease

# %%
# Countplot for Blue Light Filter vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Blue-light filter', hue='Dry Eye Disease', data=df, palette='Set1')

# Titles and labels
plt.title('Blue Light Filter Usage vs Dry Eye Disease', fontsize=16)
plt.xlabel('Blue Light Filter (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Dry Eye Disease', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# # Countplot for Male vs Female vs Dry Eye Disease

# %%
# Countplot for Male vs Female vs Dry Eye Disease
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Dry Eye Disease', data=df, palette='Set1')

# Titles and labels
plt.title('Male vs Female vs Dry Eye Disease', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Dry Eye Disease', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Ongoing medication', hue='Dry Eye Disease', data=df, palette='Set1')
plt.title('Obgoing Medication vs Dry Eye Disease', fontsize=16)
plt.xlabel('Ongoing medication (Y/N)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()
